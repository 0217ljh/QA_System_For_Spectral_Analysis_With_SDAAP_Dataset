# %%
import os
import json
import pandas as pd
from langchain.vectorstores import FAISS
from langchain.embeddings.huggingface import HuggingFaceEmbeddings
from langchain.chains import RetrievalQA
from langchain.chat_models import ChatOpenAI  
from langchain import PromptTemplate

# 设置Chat-GPT API的密钥
OPENAI_KEY = 'your_key'

# 加载Chat-GPT模型
gpt_model = ChatOpenAI(model_name='gpt-3.5-turbo', temperature=0.1, max_tokens=512, api_key=OPENAI_KEY)

# 论文文件夹路径
paper_folder = "F:\Code\Word_detecting\Vector_ku\Train_vector"

# 创建一个空的DataFrame用于保存问题、标签和论文标题
questions_df = pd.DataFrame(columns=["Paper Title", "Question", "Label"])

prompt_template = """Ask questions about the text content to generate the following five questions:
 1. What kind of spectral detection method was used in the related research of ...(the topic of the paper)? 
 2. If I use (the specific spectral detection method in the paper) to carry out in the related research of ...(the topic of the paper), What kind of feature processing methods can I take based on similar studies?
 3. If I use (the specific spectral detection method in the paper) to carry out in the related research of ...(the topic of the paper) , What kind of machine learning methods can i take based on similar studies?
 4.If I use (the specific spectral detection method in the paper) to carry out in the related research of ...(the topic of the paper) , What metric was chosen to evaluate model's performance, and how far can this metric go? (make sure you mention the specific spectral detecting method in this question!!!)
 5.You can ask anything related to the research of ...(the topic of the paper) using (the specific spectral detection method in the paper), generate questions randomly。
 dont point out the author's name,
 Notice:for the first four questions, dont use “how” to ask question ,
 In the questions gennerated, dont use words like “in the paper”, use “in the related study” instead of “in the study”,use 'in the related research' instead of 'in the research',
 Must make sure evevry question mentions the specific object of study and the specific spectral detecting method,
 You don't have to use 'if...' at all time, you can try another way to ask questions, but you must mentions mentions the specific object of study and the specific spectral detecting method,
            known information:
            {context}

            Question:
            {question}"""

# 设置每个文件保存的论文数量
batch_size = 100
# 用于记录已经处理的论文数量
processed_count = 0
# 用于记录保存的文件编号
file_number = 1

# 定义一个函数来解析论文文件名中的数字部分
def extract_paper_number(filename):
    return int(filename.split('_')[0])

# 遍历论文文件夹
for paper_filename in sorted(os.listdir(paper_folder), key=extract_paper_number):
    vs_path = os.path.join(paper_folder, paper_filename, 'Vector')
    
    # 检查路径是否存在
    if not os.path.exists(vs_path) or not os.path.isdir(vs_path):
        print(f"路径 {vs_path} 不存在或不是一个目录，跳过...")
        continue
    
    # 寻找.faiss文件
    faiss_files = [f for f in os.listdir(vs_path) if f.endswith('.faiss')]
    
    # 检查是否存在.faiss文件
    if not faiss_files:
        print(f"在路径 {vs_path} 中找不到 .faiss 文件，跳过...")
        continue
    
    index_name = faiss_files[0].split('.faiss')[0]
    print('当前论文:', index_name)

    vector_store = FAISS.load_local(vs_path, 
                                    HuggingFaceEmbeddings(model_name="BAAI/bge-small-en"),
                                    index_name=index_name,
                                    allow_dangerous_deserialization=True)
    # 构建查询问题
    query_question = f"Ask questions about the text content to generate the following five questions."
    # 使用FAISS进行文本检索
    knowledge_chain = RetrievalQA.from_llm(llm=gpt_model, 
                                           retriever=vector_store.as_retriever(search_kwargs={"k": 2}), 
                                           prompt = PromptTemplate(
                template=prompt_template,
                input_variables=["context", "question"]))
    result = knowledge_chain({"query": query_question})
    generated_questions = result['result'].split('\n')
    print("生成问题：", generated_questions) 
    # 检查是否生成了三个问题
    if len(generated_questions) != 5:
        print(f"未能生成五个问题：{generated_questions}")
        continue
    
    # 去掉问题中的序号并添加到DataFrame中
    generated_questions = [question.split('. ')[1] for question in generated_questions]

    temp_df = pd.DataFrame({
        "Paper Title": paper_filename*5,  # 使用第一个下划线后的部分作为论文标题
        "Question": generated_questions,
        "Label": ["Spectral Detection Method", "Feature Processing Method", "Mechine learning Method","Evaluated metrics","Random questions"]
    })
    questions_df = pd.concat([questions_df, temp_df], ignore_index=True)
    
    # 更新已处理的论文数量
    processed_count += 1
    
    # 检查是否达到了保存的批次大小或已处理完所有论文
    if processed_count % batch_size == 0 or processed_count == len(os.listdir(paper_folder)):
        # 将DataFrame保存到Excel文件
        excel_file = f"Questions(Five)_batch_{file_number}.xlsx" 
        questions_df.to_excel(excel_file, index=False)
        print(f"问题已保存到 {excel_file}")
        
        # 清空DataFrame以保存下一批数据
        questions_df = pd.DataFrame(columns=["Paper Title", "Question", "Label"])
        
        # 更新文件编号
        file_number += 1

print("处理完成！")
# Out:
# 当前论文: 1_Cognitive_spectroscopy_for_evaluating_Ch
# 生成问题： ['1. What kind of spectral detection method was used in the related research of predicting Japanese green tea ranking?', '2. When using Fourier transform near-infrared reflectance spectroscopy to evaluate Japanese green tea ranking, what feature processing methods can be applied based on similar studies?', '3. In the related study of predicting Japanese green tea ranking using Fourier transform near-infrared reflectance spectroscopy, what machine learning methods have been utilized in similar research?', "4. When using Fourier transform near-infrared reflectance spectroscopy to predict Japanese green tea ranking, what metric was chosen to evaluate the model's performance, and how reliable is this metric?", '5. How can the prediction of Japanese green tea ranking be improved by incorporating different machine learning algorithms with Fourier transform near-infrared reflectance spectroscopy?']
# 当前论文: 6_Diffuse_reflectance_spectroscopy_and_Ram
# 生成问题： ['1. What spectral detection method was used in the related research of bone and cartilage tissue analysis?', '2. What feature processing methods can be applied based on similar studies using spontaneous Raman spectroscopy in bone and cartilage tissue analysis?', '3. What machine learning methods can be utilized based on similar studies using spontaneous Raman spectroscopy in bone and cartilage tissue analysis?', '4. What metric was chosen to evaluate the performance of the model in bone and cartilage tissue analysis using spontaneous Raman spectroscopy, and how reliable is this metric?', '5. How does the Bayesian-based decomposition method in DRS contribute to a more accurate analysis of absorption and scattering coefficients in bone and cartilage tissue?']
# 当前论文: 7_Spectroscopy-based_food_classification_w
# 生成问题： ['1. What kind of spectral detection method was used in the related research of food classification in the study?', '2. What feature processing methods can be used in the related research of food classification using the ELM model and spectroscopy?', '3. What machine learning methods can be applied in the related research of food classification using the ELM model and spectroscopy?', "4. What metric was chosen to evaluate the ELM model's performance in the related study of food classification, and how reliable is this metric when using spectroscopy?", '5. How does the ELM model compare in terms of speed to other classification methods like KNN, LS-SVM, and BP-ANN in the study of food classification using spectroscopy?']
# 当前论文: 8_Differentiation_of_Plastics_by_Combining
# 生成问题： ['1. What kind of spectral detection method was used in the related research of plastic classification?', '2. What feature processing methods can be used in the related research of plastic classification using Raman spectral analysis?', '3. What machine learning methods can be applied in the related research of plastic classification using Raman spectral analysis?', '4. What metric was chosen to evaluate the performance of the model in the related research of plastic classification using Raman spectral analysis, and how effective is this metric?', '5. How can the F1 score be utilized in the classification of plastics based on Raman spectral analysis?']
# 当前论文: 12_Classification_of_textile_fabrics_by_use
# 生成问题： ['1. What kind of spectral detection method was used in the related research of identifying wool, cashmere, yak, and angora rabbit fibers and quantitatively determining wool and cashmere in blend?', '2. When using near-infrared spectroscopy in the textile industry, what feature processing methods can be applied based on similar studies?', '3. In the study on the identification of cotton and cotton trash components by Fourier transform near-infrared spectroscopy, what machine learning methods were utilized?', '4. What metric was chosen to evaluate the performance of the model in the rapid, non-destructive textile classification using SIMCA on diffuse near-infrared reflectance spectra, and how reliable is this metric when using SIMCA?', '5. How can extreme learning machines be applied in the classification of diabetes and the measurement of blood glucose concentration noninvasively using near-infrared spectroscopy?']
# 当前论文: 13_Combining_Fourier_Transform_Mid-Infrared
# 生成问题： ['1. What specific spectral detection method was used in the related research of detecting milk adulterated with rice flour and soybean flour?', '2. What feature processing methods can be used based on similar studies using mid-infrared spectroscopy to detect milk adulterated with rice flour and soybean flour?', '3. What machine learning methods can be applied based on similar studies using mid-infrared spectroscopy to detect milk adulterated with rice flour and soybean flour?', "4. What metric was chosen to evaluate the model's performance in detecting milk adulterated with rice flour and soybean flour using mid-infrared spectroscopy, and how reliable is this metric?", '5. How can mid-infrared spectroscopy be utilized to differentiate between milk powder, rice flour, soybean flour, and adulterated milk powder with rice flour and soybean flour in the related study?']
# 当前论文: 14_Random_Forest-Based_Evaluation_of_Raman_
# 生成问题： ['1. What kind of spectral detection method was used in the related research of developing the RFRS-DengD system for dengue diagnosis?', '2. What feature processing methods can be applied to the Raman spectra data obtained from serum samples in the related study of developing the RFRS-DengD system for dengue diagnosis?', '3. What machine learning methods were utilized in the related research of developing the RFRS-DengD system for dengue diagnosis using Raman spectroscopy?', "4. What metric was chosen to evaluate the performance of the RF-based model in the related study of developing the RFRS-DengD system for dengue diagnosis using Raman spectroscopy, and how effective is this metric in assessing the model's performance?", '5. How does the RFRS-DengD system differentiate between normal and infected samples based on the Raman spectra of human blood sera in the related study of dengue diagnosis using Raman spectroscopy?']
# 当前论文: 17_NIR_Spectroscopy_Oranges_Origin_Identifi
# 生成问题： ['1. What spectral detection method was used in the related research of identifying the origin of oranges?', '2. What feature processing methods can be used based on similar studies if the specific spectral detection method used in the research is applied to identify the origin of oranges?', '3. What machine learning methods can be used based on similar studies if the specific spectral detection method used in the research is applied to identify the origin of oranges?', "4. What metric was chosen to evaluate the model's performance in the related study of identifying the origin of oranges using the specific spectral detection method, and how reliable is this metric?", '5. How were the original spectra of oranges preprocessed in the related research using the specific spectral detection method, and what were the results of the preprocessing methods used?']
# 当前论文: 20_An_efficient_primary_screening_of_COVID-
# 生成问题： ['1. What specific spectral detection method was used in the related research of COVID-19 patients, suspected cases, and healthy controls?', "2. What feature processing methods can be applied to the Raman spectra data of COVID-19 patients, suspected cases, and healthy controls based on the study's findings?", '3. What machine learning methods can be utilized with the Raman spectra data of COVID-19 patients, suspected cases, and healthy controls according to similar studies?', '4. What metric was chosen to evaluate the performance of the SVM model using the Raman spectra data of COVID-19 patients, suspected cases, and healthy controls, and how reliable is this metric?', '5. How can the Raman spectra data of COVID-19 patients, suspected cases, and healthy controls be further analyzed to improve diagnostic algorithms and differentiate between the groups effectively?']
# 当前论文: 21_Deep_learning_methods_for_oral_cancer_de
# 生成问题： ['1. What kind of spectral detection method was used in the related research of oral cancer and normal tissues?', '2. What feature processing methods can be applied to Raman spectral data of oral cancer and normal tissues based on similar studies?', '3. What machine learning methods can be used with Raman spectral data of oral cancer and normal tissues based on similar studies?', '4. What metric was chosen to evaluate the performance of the AlexNet model in classifying oral cancer and normal tissues, and how does it compare to the other models?', '5. How did the VGGNet model perform in classifying oral cancer and normal tissues compared to the AlexNet model?']
# 当前论文: 22_Towards_fruit_maturity_estimation_using_
# 生成问题： ['1. What kind of spectral detection method was used in the related research of fruit ripening assessment and their correlation with internal characteristics?', '2. What feature processing methods can be used in the related study of fruit ripening assessment and their correlation with internal characteristics when using near infrared spectroscopy (NIRS)?', '3. What machine learning methods can be applied in the related study of fruit ripening assessment and their correlation with internal characteristics when using near infrared spectroscopy (NIRS)?', "4. What metric was chosen to evaluate the model's performance in the related study of fruit ripening assessment and their correlation with internal characteristics when using near infrared spectroscopy (NIRS), and how effective is this metric?", '5. How can near infrared spectroscopy (NIRS) be utilized in the research of fruit ripening assessment and their correlation with internal characteristics, and what are the potential applications for different fruits?']
# 当前论文: 23_Garlic_bulb_classification_by_combining_
# 生成问题： ['1. What kind of spectral detection method was used in the related research of garlic classification?', '2. What feature processing methods can be used based on similar studies using Raman spectroscopy for garlic classification?', '3. What machine learning methods can be applied in the related research of garlic classification using Raman spectroscopy?', '4. What metric was chosen to evaluate the performance of the model in the related study of garlic classification using Raman spectroscopy, and how effective is this metric?', '5. How does the data dimension reduction process, including PCA, t-SNE, and LDA, contribute to the analysis of Raman spectra for garlic classification?']
# 当前论文: 24_Research_on_Soybean_Bacterial_Disease_Ma
# 生成问题： ['1. What kind of spectral detection method was used in the related research of the topic discussed in the paper?', '2. When using the specific spectral detection method mentioned in the study for the related research, what feature processing methods can be implemented based on similar studies?', '3. When utilizing the specific spectral detection method in the related research, what machine learning methods can be applied based on similar studies?', "4. What metric was selected to evaluate the model's performance when using the specific spectral detection method in the related research, and how effective is this metric?", '5. How does the specific spectral detection method discussed in the paper contribute to advancements in the related research field?']
# 当前论文: 26_Classification_of_printing_inks_in_pharm
# 生成问题： ['1. What kind of spectral detection method was used in the related research of classifying printing inks in pharmaceutical packages?', '2. What feature processing methods can be used based on similar studies if using Laser-Induced Breakdown Spectroscopy and Attenuated Total Reflectance-Fourier Transform Infrared Spectroscopy in the related research of printing inks in pharmaceutical packages?', '3. What machine learning methods can be used based on similar studies if using Laser-Induced Breakdown Spectroscopy and Attenuated Total Reflectance-Fourier Transform Infrared Spectroscopy in the related research of printing inks in pharmaceutical packages?', "4. What metric was chosen to evaluate the model's performance when using Laser-Induced Breakdown Spectroscopy and Attenuated Total Reflectance-Fourier Transform Infrared Spectroscopy in the related research of classifying printing inks in pharmaceutical packages, and how effective is this metric?", '5. How can the complementary characteristics of ATR-FTIR and LIBS provide valuable information for the examination of counterfeit packages in the related study of printing inks in pharmaceutical packages?']
# 当前论文: 28_A_novel_detection_technology_for_early_g
# 生成问题： ['1. What spectral detection method was used in the related research of gastric cancer detection?', '2. What feature processing methods can be applied in the related research of gastric cancer detection using Raman spectroscopy?', '3. What machine learning methods can be utilized in the related research of gastric cancer detection using Raman spectroscopy?', '4. What metric was chosen to evaluate the performance of the model in the related study of gastric cancer detection using Raman spectroscopy, and how effective is this metric?', '5. How can Raman spectroscopy be beneficial in identifying precancerous lesions and early-stage cancers in the context of gastric cancer detection?']
# 当前论文: 30_Diagnosis_of_Citrus_Greening_using_Raman
# 生成问题： ['1. What spectral detection method was used in the related research of Raman leaf spectra analysis?', '2. What feature processing methods can be applied in the related research of Raman leaf spectra analysis using PCA and SPA?', '3. What machine learning methods can be utilized in the related research of Raman leaf spectra analysis with PCA and SPA?', '4. What metric was chosen to evaluate the performance of the model in the related study of Raman leaf spectra analysis using PCA and SPA, and how effective is this metric?', '5. How can PLS-DA and ELM qualitative analysis improve the accuracy of discrimination in the related research of Raman leaf spectra analysis?']
# 当前论文: 34_How_Well_Can_Reflectance_Spectroscopy_Al
# 生成问题： ['1. What spectral detection method was used in the related research of soil fertility allocation to soil fertility classes?', '2. What feature processing methods can be applied in the related study of soil fertility allocation to soil fertility classes using visible and near-infrared spectroscopy?', '3. What machine learning methods can be utilized in the related study of soil fertility allocation to soil fertility classes using visible and near-infrared spectroscopy?', "4. What metric was chosen to evaluate the model's performance in the related study of soil fertility allocation to soil fertility classes using visible and near-infrared spectroscopy, and how reliable is this metric?", '5. How does the allocation accuracy in the related study of soil fertility allocation to soil fertility classes using visible and near-infrared spectroscopy get influenced by the specification of user-defined thresholds?']
# 当前论文: 35_Towards_a_fast_and_generalized_microplas
# 生成问题： ['1. What kind of spectral detection method was used in the related research of microplastic pollution in soil samples?', '2. When using terahertz absorbance spectrum in the related study of microplastic pollution in soil samples, what feature processing methods can be applied based on similar studies?', '3. In the related research of microplastic pollution in soil samples using terahertz absorbance spectrum, what machine learning methods can be utilized based on similar studies?', "4. When using terahertz absorbance spectrum in the related study of microplastic pollution in soil samples, what metric was chosen to evaluate the model's performance, and how effective is this metric?", '5. How do the additives in household plastic samples affect the terahertz absorption spectrum in the study of microplastic pollution in soil samples using terahertz absorbance spectrum?']
# 当前论文: 38_Human_serum_mid-infrared_spectroscopy_co
# 生成问题： ['1. What kind of spectral detection method was used in the related research of glioma patients and healthy volunteers?', '2. What feature processing methods can be used based on similar studies using mid-infrared spectroscopy for glioma diagnosis?', '3. What machine learning methods can be applied based on similar studies using mid-infrared spectroscopy for glioma diagnosis?', '4. What metric was chosen to evaluate the performance of the PCA-PSO-SVM classification model in the study on glioma diagnosis using mid-infrared spectroscopy?', '5. How can mid-infrared spectroscopy be utilized for the rapid, accurate, and low-cost diagnosis of glioma patients according to the study findings?']
# 当前论文: 54_Combining_Raman_spectroscopy_and_machine
# 生成问题： ['1. What kind of spectral detection method was used in the related research of Spectrochimica Acta Part A: Molecular and Biomolecular Spectroscopy?', '2. When using Raman spectra measurement in the related research of Spectrochimica Acta Part A: Molecular and Biomolecular Spectroscopy, what feature processing methods can be applied based on similar studies?', '3. In the related research of Spectrochimica Acta Part A: Molecular and Biomolecular Spectroscopy, what machine learning methods can be utilized when using Raman spectra measurement?', "4. What metric was chosen to evaluate the model's performance in the related research of Spectrochimica Acta Part A: Molecular and Biomolecular Spectroscopy when using Raman spectra measurement, and how reliable is this metric?", '5. How can the findings of the research in Spectrochimica Acta Part A: Molecular and Biomolecular Spectroscopy using Raman spectra measurement contribute to advancements in the field?']
# 当前论文: 57_Diagnosis_of_Diabetes_Based_on_Analysis_
# 生成问题： ['1. What kind of spectral detection method was used in the related research of analyzing exhaled air of patients with DM and healthy volunteers?', '2. How can feature processing methods be applied based on similar studies using terahertz time-domain (TD) spectroscopy in the analysis of exhaled air samples?', '3. What machine learning methods can be utilized based on similar studies using terahertz time-domain (TD) spectroscopy in the analysis of exhaled air samples?', "4. What metric was chosen to evaluate the model's performance in distinguishing between patients with DM and healthy volunteers using terahertz time-domain (TD) spectroscopy, and how reliable is this metric?", '5. How can terahertz time-domain (TD) spectroscopy be utilized as a diagnostic tool for estimating the possibility of using exhaled air as a diagnostic agent in the research of patients with DM and healthy volunteers?']
# 当前论文: 59_Label-Free_Identification_of_Exosomes_us
# 生成问题： ['1. What specific spectral detection method was used in the related study of EV isolation from various cell lines?', '2. What feature processing methods can be applied when using the Exosome Total Isolation Chip-ExoTIC for EV isolation from different cell lines?', '3. What machine learning methods can be utilized when employing the Exosome Total Isolation Chip-ExoTIC for EV isolation from different cell lines?', '4. What metric was chosen to evaluate the performance of the Exosome Total Isolation Chip-ExoTIC in isolating EVs from various cell lines, and how reliable is this metric?', '5. How can the Exosome Total Isolation Chip-ExoTIC be optimized for more efficient EV isolation from different cell lines in future studies?']
# 当前论文: 63_Classification_and_Recognition_of_Lilies
# 生成问题： ['1. What kind of spectral detection method was used in the related research of the specific object of study?', '2. What feature processing methods can be applied in the related research of the specific object of study using the specific spectral detection method?', '3. What machine learning methods have been utilized in similar studies of the specific object of study with the specific spectral detection method?', '4. What metric was chosen to evaluate the performance of models in the related research of the specific object of study using the specific spectral detection method, and how effective is this metric?', '5. How does the specific spectral detection method impact the results and findings in the related research of the specific object of study?']
# 当前论文: 72_Identification_of_Aspergillus_species_in
# 生成问题： ['1. What spectral detection method was used in the related research of identifying fungal and bacterial isolates in the study?', '2. What feature processing methods can be employed if using MALDI-TOF identification to carry out research on fungal growth and identification?', '3. What machine learning methods can be utilized if using 18S rRNA sequencing to study fungal isolates in the related research?', '4. What metric was chosen to evaluate the performance of the model when using large subunit ribosomal DNA primers and internal transcribed spacer sequencing, and how reliable is this metric?', '5. How were the positive and negative samples prepared in the Basic Set of the study, and what was the purpose of this set in the research?']
# 当前论文: 81_An_application_of_raman_spectroscopy_in_
# 生成问题： ['1. What specific spectral detection method was used in the related research of identifying gastric cancer patients?', '2. What feature processing methods were employed in similar studies using the specific spectral detection method in the research of gastric cancer patients?', '3. What machine learning methods were utilized in similar studies using the specific spectral detection method in the research of gastric cancer patients?', "4. What metric was chosen to evaluate the model's performance in identifying gastric cancer patients using the specific spectral detection method, and how effective was this metric?", '5. How were decision tree construction experiments used in the research of identifying gastric cancer patients with the specific spectral detection method, and what were the results obtained?']
# 当前论文: 93_Characterizing_viral_samples_using_machi
# 生成问题： ['1. What spectral detection method was used in the related study of the ProQuad® vaccine dilutions?', '2. When using the Renishaw in ViaTMQontor confocal Raman microscope to study the ProQuad® vaccine dilutions, what feature processing methods can be applied based on similar studies?', '3. When using the Renishaw in ViaTMQontor confocal Raman microscope to study the ProQuad® vaccine dilutions, what machine learning methods can be utilized based on similar studies?', "4. When using the Renishaw in ViaTMQontor confocal Raman microscope to study the ProQuad® vaccine dilutions, what metric was chosen to evaluate the model's performance, and how reliable is this metric?", '5. How does the use of the Renishaw in ViaTMQontor confocal Raman microscope impact the accuracy of predictions in the related study of the ProQuad® vaccine dilutions?']
# 当前论文: 97_Identification_of_the_animal_origin_of_m
# 生成问题： ['1. What specific spectral detection method was used in the related research of milk samples by LIBS technique?', '2. What feature processing methods can be applied based on similar studies using the specific spectral detection method in the related research of milk samples?', '3. What machine learning methods can be utilized based on similar studies using the specific spectral detection method in the related research of milk samples?', "4. What metric was chosen to evaluate the model's performance in the related research of milk samples using the specific spectral detection method, and how far can this metric go?", '5. How do the predictive accuracies differ when using the entire LIBS spectra compared to using only five spectral lines in the related research of milk samples?']
# 当前论文: 108_Rapid_Identification_of_Rainbow_Trout_Ad
# 生成问题： ['1. What kind of spectral detection method was used in the related research of detecting the adulteration of Atlantic salmon using rainbow trout?', '2. What feature processing methods can be used in the related research of detecting the adulteration of Atlantic salmon using rainbow trout based on similar studies using Raman spectroscopy?', '3. What machine learning methods can be applied in the related research of detecting the adulteration of Atlantic salmon using rainbow trout based on similar studies using Raman spectroscopy?', '4. What metric was chosen to evaluate the performance of the regression model in detecting the adulteration of Atlantic salmon using rainbow trout with the Raman spectroscopy method, and how effective is this metric?', '5. How did the combination of Raman spectroscopy and machine learning contribute to the rapid detection of the adulteration of Atlantic salmon using rainbow trout in the related study?']
# 当前论文: 111_Predicting_the_onset_of_preeclampsia_by_
# 生成问题： ['1. What spectral detection method was used in the related research of metabolic profiling in high-risk patients for preeclampsia and other prenatal diseases?', '2. What feature processing methods can be applied to the spectral data obtained from Raman spectroscopy in the related study of metabolic profiling in high-risk patients for preeclampsia?', '3. What machine learning methods can be utilized with the spectral data obtained from Raman spectroscopy in the related research of metabolic profiling in high-risk patients for preeclampsia?', '4. What metric was chosen to evaluate the performance of the model using Raman spectroscopy in the related study of metabolic profiling in high-risk patients for preeclampsia, and how reliable is this metric?', '5. How was the separation between healthy and preeclampsia groups visualized using tSNE with the normalized Raman spectra in the related study of metabolic profiling in high-risk patients for preeclampsia?']
# 当前论文: 112_Detection_and_Recognition_of_Volatile_Su
# 生成问题： ['1. What kind of spectral detection method was used in the related research of detecting and recognizing the volatile components of mothballs in indoor environments?', '2. If I use Raman spectroscopy to analyze synthetic mothballs and natural camphor, what characteristic peaks can I expect to see in the Raman spectra?', '3. What machine learning methods were used in the related research of detecting and recognizing the volatile components of mothballs in indoor environments based on the spectral data obtained?', '4. What metric was chosen to evaluate the performance of the PCA-SVC model in identifying the spectra of air and volatile substances in synthetic mothballs and natural camphor, and how accurate was the model?', '5. How can the characteristic lines representing the C2 free radical be utilized as markers in the detection of synthetic mothballs at high concentrations based on the spectral data obtained?']
# 当前论文: 113_Anomaly_detection_in_Fourier_transform_i
# 生成问题： ['1. What spectral detection method was used in the related research of anomaly detection in Fourier transform infrared spectroscopy of geological specimens using variational autoencoders?', '2. What feature processing methods can be used in the related research of anomaly detection in Fourier transform infrared spectroscopy of geological specimens using variational autoencoders, if the specific spectral detection method mentioned in the study is employed?', '3. What machine learning methods can be used in the related research of anomaly detection in Fourier transform infrared spectroscopy of geological specimens using variational autoencoders, if the specific spectral detection method mentioned in the study is employed?', "4. What metric was chosen to evaluate the model's performance in the related research of anomaly detection in Fourier transform infrared spectroscopy of geological specimens using variational autoencoders, and how far can this metric go with the specific spectral detection method mentioned in the study?", '5. How can the latent space be leveraged in the related research of anomaly detection in Fourier transform infrared spectroscopy of geological specimens using variational autoencoders, if the specific spectral detection method mentioned in the study is utilized?']
# 当前论文: 132_Fast_and_Accurate_Discrimination_of_Brac
# 生成问题： ['1. What kind of spectral detection method was used in the related research of discriminating Brachiaria brizantha seeds?', '2. When using Fourier transformed infrared (FTIR) spectroscopy to classify Brachiaria brizantha seeds, what feature processing methods can be applied based on similar studies?', '3. When using Fourier transformed infrared (FTIR) spectroscopy to classify Brachiaria brizantha seeds, what machine learning methods can be utilized based on similar studies?', "4. When using Fourier transformed infrared (FTIR) spectroscopy to classify Brachiaria brizantha seeds, what metric was chosen to evaluate the model's performance, and how reliable is this metric?", '5. How can molecular spectroscopy combined with machine learning analysis be beneficial for the classification of Brachiaria brizantha seeds?']
# 当前论文: 134_Analysis_and_comparison_of_machine_learn
# 生成问题： ['1. What spectral detection method was used in the related research of blood cell classification by single-cell Raman spectroscopy?', '2. What feature processing methods can be used based on similar studies when using the Boruta algorithm to extract important features in blood cell classification research?', '3. What machine learning methods can be utilized based on similar studies when using the Boruta algorithm to extract important features in blood cell classification research?', '4. What metric was chosen to evaluate the performance of machine learning models in blood cell classification using Raman spectroscopy, and how stable is the accuracy when selecting 30 important features?', '5. How can the confusion matrix be used to calculate various indicators for evaluating the prediction performance of different machine learning algorithms in blood cell classification research?']
# 当前论文: 148_Using_near-infrared_spectroscopy_and_a_r
# 生成问题： ['1. What specific spectral detection method was used in the related study on estimating intracranial pressure in non-human primates?', '2. What feature processing methods can be applied when using diffuse optics to estimate intracranial pressure in a proof-of-concept study?', '3. What machine learning methods have been utilized in the research on estimating intracranial pressure using diffuse correlation spectroscopy?', '4. What metric was chosen to evaluate the performance of estimating intracranial pressure non-invasively using near-infrared spectroscopy in non-human primates, and how reliable is this metric?', '5. How can the relationship between intracranial pressure and heart variability signals be characterized using causal spectral measures and generalized synchronization measures in the context of diffuse correlation spectroscopy?']
# 当前论文: 151_Online_near-infrared_spectroscopy_for_au
# 生成问题： ['1. What kind of spectral detection method was used in the related research of distinguishing PLA and ABS samples based on their absorption of near-infrared radiation?', '2. How can feature processing methods be applied to spectral data of PLA, ABS, and PETG filament samples based on the exploratory analysis results in the related study?', '3. What machine learning methods were utilized in the related research of classifying PLA, ABS, and PETG polymer filament spectra using the LDA method?', '4. What metric was chosen to evaluate the performance of the classification model in the related study that utilized the LDA method for spectral data analysis, and how reliable is this metric in assessing model accuracy?', '5. How did the enhanced classification algorithm in the related study contribute to the separation and treatment of spectral data for constructing decision planes in the LDA model?']
# 当前论文: 159_Near-Infrared_Spectroscopy_Combined_With
# 生成问题： ['1. What kind of spectral detection method was used in the related research of predicting the origin of Aconitum carmichaeli?', '2. When using the principal component analysis on the original spectra in the related study of predicting the origin of Aconitum carmichaeli, what feature processing methods can be applied based on similar studies?', '3. In the related research of predicting the origin of Aconitum carmichaeli using the original spectra, what machine learning methods can be utilized based on similar studies?', "4. What metric was chosen to evaluate the model's performance in predicting the origin of Aconitum carmichaeli using the original spectra, and how reliable is this metric in assessing the model's accuracy?", '5. How can machine learning be applied to explore the data in predicting the origin of Aconitum carmichaeli using the original spectra, considering the spectral characteristics mentioned in the study?']
# 当前论文: 163_Non-Invasive_In_Vivo_Type_2_Diabetes_Mel
# 生成问题： ['1. What kind of spectral detection method was used in the related research of non-invasive blood glucose testing?', '2. What kind of feature processing methods can be used in the related research of non-invasive blood glucose testing using Raman spectroscopy?', '3. What machine learning methods can be applied in the related research of non-invasive blood glucose testing using Raman spectroscopy?', '4. What metric was chosen to evaluate the performance of the model in the related research of non-invasive blood glucose testing using Raman spectroscopy, and how accurate is this metric?', '5. How can Raman spectroscopy be utilized in non-invasive blood glucose monitoring, and what are the advantages of using this method over other techniques?']
# 当前论文: 168_Machine_Learning-Based_Heavy_Metal_Ion_D
# 生成问题： ['1. What spectral detection method was used in the related research of heavy metal ion detection using surface-enhanced Raman spectroscopy?', '2. What feature processing methods can be used in the related research of heavy metal ion detection using surface-enhanced Raman spectroscopy with the specific spectral detection method mentioned in the study?', '3. What machine learning methods can be applied in the related research of heavy metal ion detection using surface-enhanced Raman spectroscopy with the specific spectral detection method mentioned in the study?', "4. What metric was chosen to evaluate the model's performance in the related research of heavy metal ion detection using surface-enhanced Raman spectroscopy with the specific spectral detection method mentioned in the study, and how far can this metric go?", "5. How can the surface-enhanced Raman spectroscopy technique be utilized for heavy metal ion detection in water based on the study's findings?"]
# 当前论文: 196_Ammonium_perchlorate_moisture_quantitati
# 生成问题： ['1. What kind of spectral detection method was used in the related research of detecting the moisture content of AP?', '2. What feature processing methods can be used in the related research of detecting the moisture content of AP using THz-TDS technology?', '3. What machine learning methods were utilized in the related research of detecting the moisture content of AP using THz-TDS technology?', '4. What metric was chosen to evaluate the performance of the GA-ELM model in predicting the moisture content of AP, and how accurate were the predictions?', '5. How did the study demonstrate the feasibility and superiority of terahertz technology in quantitative analysis of moisture content in AP and similar substances?']
# 当前论文: 206_Non-Perturbative_Identification_and_Subt
# 生成问题： ['1. What spectral detection method was used in the related research of identifying and subtyping amyloidosis in human kidney tissue?', '2. What feature processing methods can be used based on similar studies when using Raman spectroscopy to study amyloidosis in human kidney tissue?', '3. What machine learning methods can be applied based on similar studies when using Raman spectroscopy to study amyloidosis in human kidney tissue?', '4. What metric was chosen to evaluate the performance of the model when using Raman spectroscopy to study amyloidosis in human kidney tissue, and how effective is this metric?', '5. How does t-SNE contribute to the analysis of Raman spectra in the study of amyloidosis in human kidney tissue using Raman spectroscopy and machine learning techniques?']
# 当前论文: 219_Estimating_Nitrogen_Concentration_of_Rub
# 生成问题： ['1. What kind of spectral detection method was used in the related research of the specific object of study?', '2. What feature processing methods can be applied in the related research of the specific object of study using the specific spectral detection method?', '3. What machine learning methods have been utilized in similar studies for the specific object of study using the specific spectral detection method?', '4. What metric was chosen to evaluate the performance of models in the related research of the specific object of study using the specific spectral detection method, and how reliable is this metric?', '5. How does the specific spectral detection method in the related research of the specific object of study contribute to advancements in the field?']
# 当前论文: 220_Detection_of_breast_cancer_of_various_cl
# 生成问题： ['1. What kind of spectral detection method was used in the related research of breast cancer classification and quantitative analysis?', '2. What feature processing methods can be used in the related research of breast cancer classification and quantitative analysis when using FT-IR spectroscopy for spectral detection?', '3. What machine learning methods can be applied in the related research of breast cancer classification and quantitative analysis when using FT-IR spectroscopy for spectral detection?', '4. What metric was chosen to evaluate the performance of the classification models in the related study of breast cancer classification and quantitative analysis using FT-IR spectroscopy, and how accurate were the results?', '5. How do the differences in biomolecules provide a solid base for the classification experiments of different stages of breast cancer and non-cancer control subjects using FT-IR spectroscopy?']
# 当前论文: 228_Rapid_Identification_of_Kudzu_Powder_of_
# 生成问题： ['1. What method was used to select characteristic wavelengths in the spectral analysis of different kudzu powders?', '2. What machine learning methods were mentioned in the study for discriminant analysis of the different kudzu powders?', "3. What metric was chosen to evaluate the model's performance in the study of different kudzu powders using the Extreme Learning Machine (ELM) method?", '4. How was the discriminant analysis method of Random Forest (RF) described in the study of different kudzu powders?', '5. How were the original spectra of different kudzu powders analyzed in the study, and what specific emission lines were observed?']
# 当前论文: 246_Rapid_determination_by_near_infrared_spe
# 生成问题： ['1. What spectral detection method was used in the related research of the fermentation process of Congou black tea?', '2. What feature processing methods can be applied based on similar studies using the spectral detection method in the research of tea fermentation?', '3. What machine learning methods can be utilized in the related research of tea fermentation using the specific spectral detection method mentioned in the study?', '4. What metric was chosen to evaluate the performance of the PLS model in the study of tea fermentation using the SNVT spectral pretreatment method?', '5. How can principal component analysis be used to analyze the spectral data in the research of tea fermentation with the specific spectral detection method mentioned in the study?']
# 当前论文: 264_Imaging_spectroscopy_predicts_variable_d
# 生成问题： ['1. What spectral detection method was used in the related research of the accepted article?', '2. What feature processing methods can be applied in the related study using the specific spectral detection method mentioned in the accepted article?', '3. What machine learning methods have been utilized in similar studies using the specific spectral detection method mentioned in the accepted article?', "4. What metric was selected to evaluate the model's performance in the related research using the specific spectral detection method mentioned in the accepted article, and how reliable is this metric?", '5. How can the findings of the accepted article be applied in practical scenarios involving the specific spectral detection method mentioned in the study?']
# 当前论文: 270_Prediction_of_Eggplant_Leaf_F-v_F-m_Base
# 生成问题： ['1. What kind of spectral detection method was used in the related research of the specific object of study?', '2. What feature processing methods can be applied if using the specific spectral detection method in the related research of the specific object of study?', '3. What machine learning methods have been utilized in similar studies when using the specific spectral detection method in the related research of the specific object of study?', "4. What metric was chosen to evaluate the model's performance when using the specific spectral detection method in the related research of the specific object of study, and how reliable is this metric?", '5. How does the specific spectral detection method in the related research of the specific object of study contribute to advancements in the field?']
# 当前论文: 297_Evaluation_of_Steels_Susceptibility_to_H
# 生成问题： ['1. What was the specific spectral detection method used in the related study of the development of the regression ANN model?', '2. What feature processing methods can be employed based on similar studies if the specific spectral detection method used in the related research is utilized for the study?', '3. What machine learning methods can be implemented based on similar studies if the specific spectral detection method used in the related research is utilized for the study?', "4. What metric was chosen to evaluate the performance of the model developed using the specific spectral detection method in the related research, and how effective is this metric in assessing the model's accuracy?", '5. How did the correlation analysis of the fitting parameters with the HSP values in the related study using the specific spectral detection method provide insights into the relationship between different parameters?']
# 当前论文: 299_Rapid_detection_of_copper_ore_grade_base
# 生成问题： ['1. What kind of spectral detection method was used in the related research of detecting the non-linear relationship between visible-infrared spectral data and the grade of copper ore?', '2. If I use the APaRP method to carry out in the related research of detecting non-linear relationships, what kind of feature processing methods can I take based on similar studies?', '3. If I use the PaRP method to carry out in the related research of modeling the ore grade, what machine learning methods can I take based on similar studies?', "4. What metric was chosen to evaluate the model's performance in the related study of using the APaRP method to detect non-linear relationships, and how far can this metric go?", '5. How can the Runs test be used to evaluate the degree of non-linearity in the spectral data in the related research of modeling the ore grade using the TELM method?']
# 当前论文: 310_Rapid_monitoring_approaches_for_concentr
# 生成问题： ['1. What kind of spectral detection method was used in the related research of monitoring the indicators and detecting the end point of concentration process of LOS by NIRs?', '2. What feature processing methods can be used based on similar studies if the genetic algorithm joint extreme learning machine (GA-ELM) spectral detection method is applied in the related research of monitoring the concentration process of LOS?', '3. What machine learning methods can be utilized based on similar studies if the genetic algorithm joint extreme learning machine (GA-ELM) spectral detection method is used in the related research of monitoring the concentration process of LOS?', "4. What metric was chosen to evaluate the model's performance in the related study of monitoring the concentration process of LOS using the genetic algorithm joint extreme learning machine (GA-ELM) spectral detection method, and how reliable is this metric?", '5. How can the genetic algorithm joint extreme learning machine (GA-ELM) spectral detection method be optimized for real-time detection of LOS and intelligent control in the continuous production process based on the findings of the related study?']
# 当前论文: 321_Desert_Soil_Salinity_Inversion_Models_Ba
# 生成问题： ['1. What kind of spectral detection method was used in the related research of soil samples in the study area?', '2. When using the FieldSpec4 geo physical spectrometer from ASD, USA to measure soil samples, what feature processing methods can be applied based on similar studies?', '3. When using the FieldSpec4 geo physical spectrometer from ASD, USA to measure soil samples, what machine learning methods can be utilized based on similar studies?', "4. When using the FieldSpec4 geo physical spectrometer from ASD, USA to measure soil samples, what metric was chosen to evaluate the model's performance, and how effective is this metric in assessing the model's accuracy?", '5. How do different feature band selection methods impact the prediction accuracy of soil salt models when using the FieldSpec4 geo physical spectrometer from ASD, USA?']
# 当前论文: 323_Quantitative_Analysis_of_Total_Phenol_Co
# 生成问题： ["1. What specific spectral detection method was used in the related study of the neural network model's performance?", "2. What feature processing methods can be employed based on similar studies using the specific spectral detection method in the related research of the neural network model's performance?", "3. What machine learning methods can be utilized based on similar studies using the specific spectral detection method in the related research of the neural network model's performance?", "4. What metric was chosen to evaluate the model's performance in the related study of the neural network model's performance using the specific spectral detection method, and how effective is this metric?", "5. How did the number of hidden layer neurons impact the model's predictive ability in the related research of the neural network model's performance using the specific spectral detection method?"]
# 当前论文: 327_TeaNet__Deep_learning_on_Near-Infrared_S
# 生成问题： ['1. What kind of spectral detection method was used in the related research of tea classification mentioned in the text?', '2. What feature processing methods can be applied to the spectral data collected from the NIR spectrometer for tea quality classification?', '3. What machine learning methods were utilized in the related research of tea classification using the SupNIR-2720 spectrometer?', '4. What metric was chosen to evaluate the performance of the model developed using the SupNIR-2720 spectrometer for tea quality classification, and how accurate was the classification achieved?', '5. How does the SupNIR-2720 spectrometer differ from other spectrometers mentioned in the text in terms of data acquisition and analysis for tea classification research?']
# 当前论文: 331_Advancing_cancer_diagnostics_with_artifi
# ...
# 当前论文: 4321_Comparison_of_phycocyanin_concentrations
# 生成问题： ['1. What spectral detection method was used in the related study of PC concentration retrieval in Chaohu Lake?', '2. What feature processing methods can be used based on similar studies using the spectral detection method in the study of PC concentration retrieval in Chaohu Lake?', '3. What machine learning methods can be applied based on similar studies using the spectral detection method in the study of PC concentration retrieval in Chaohu Lake?', "4. What metric was chosen to evaluate the model's performance in the study of PC concentration retrieval in Chaohu Lake using the spectral detection method, and how reliable is this metric?", '5. How can the spectral detection method used in the study of PC concentration retrieval in Chaohu Lake be applied to improve the accuracy of water quality parameter retrieval in other freshwater lakes?']
# 当前论文: 4342_Remote_Estimation_of_Water_Quality_Param
# 生成问题： ['1. What are the sensitive bands for NH3-N and COD according to the research in the related study?', '2. What machine learning methods can be used for the remote sensing inversion of water quality parameters using Sentinel-2 satellite images?', "3. What metric was chosen to evaluate the model's performance in estimating TP concentration using Band 1, Band 4, and Band 11 in the related study?", '4. How does the spatial distribution of NH3-N, COD, and TP in the Xinyang section of Huaihe River Basin impact the overall water quality in the study area?', '5. How does the super-resolution technology contribute to improving the reliability of data support for accurate inversion of water quality parameters using Sentinel-2 satellite images?']
# 当前论文: 4354_Multi-Species_Inference_of_Exotic_Annual
# 生成问题： ['1. What spectral detection method was used in the related research of mapping exotic annuals and native perennial grasses?', '2. When using NDWI time-series data in the related research of mapping exotic annuals and native perennial grasses, what feature processing methods can be applied based on similar studies?', '3. In the related research of mapping exotic annuals and native perennial grasses using NDVI and NDWI, what machine learning methods can be utilized based on similar studies?', "4. When using NDWI time-series data in the related research of mapping exotic annuals and native perennial grasses, what metric was chosen to evaluate the model's performance, and how reliable is this metric in assessing the model's accuracy?", '5. How did the spectral data and weather conditions influence the estimation of cover and growth patterns of exotic annuals and native perennial grasses in the study?']
# 当前论文: 4361_Machine-Learning-Based_Regional_Yield_Fo
# 生成问题： ['1. What spectral detection method was used in the related research of predicting regional yield for the state of Uttar Pradesh?', '2. What feature processing methods can be employed based on similar studies using the FPAR, LAI, and NDVI variables in predicting sugarcane yield?', '3. What machine learning methods can be utilized based on similar studies using the FPAR, LAI, and NDVI variables in predicting sugarcane yield?', "4. What metric was chosen to evaluate the performance of the gradient boosting model in predicting the regional yield for the year 2019, and how reliable is this metric in assessing the model's accuracy?", '5. How do features of FPAR, LAI, and NDVI correlate with the yield in predicting sugarcane yield, and how do these correlations vary throughout the year?']
# 当前论文: 4368_Large-scale_digital_mapping_of_topsoil_t
# 生成问题： ['1. What kind of spectral detection method was used in the related research of mapping surface soil total nitrogen content?', '2. If I use the spectral detection method in the related research of mapping surface soil total nitrogen content, what feature processing methods can I consider based on similar studies?', '3. If I use the spectral detection method in the related research of mapping surface soil total nitrogen content, what machine learning methods can I apply based on similar studies?', "4. What metric was chosen to evaluate the model's performance in mapping surface soil total nitrogen content, and how effective is this metric when using the specific spectral detection method?", '5. How do environmental covariates, such as geomorphometric parameters and vegetation indices, influence the spatial variability of topsoil total nitrogen content in the study area?']
# 当前论文: 4373_Prototyping_Sentinel-2_green_LAI_and_bro
# 生成问题： ['1. What kind of spectral detection method was used in the related research of chronic pain and neuroplasticity?', '2. If I use spectral detection methods to study chronic pain and neuroplasticity, what feature processing methods can I apply based on similar studies?', '3. If I use spectral detection methods to study chronic pain and neuroplasticity, what machine learning methods can I utilize based on similar studies?', "4. If I use spectral detection methods to study chronic pain and neuroplasticity, what metric was chosen to evaluate the model's performance, and how reliable is this metric?", '5. How can spectral detection methods be applied in the research of chronic pain and neuroplasticity to enhance understanding and treatment approaches?']
# 当前论文: 4381_Retrieval_of_oceanic_chlorophyll_concent
# 生成问题： ['1. What kind of spectral detection method was used in the related research of [Chl-𝑎] retrieval from ABI data?', '2. What feature processing methods can be employed if using the neural networks with fully connected hidden layers for [Chl-𝑎] retrieval from ABI data?', '3. What machine learning methods can be utilized if using the neural networks with fully connected hidden layers for [Chl-𝑎] retrieval from ABI data?', "4. What metric was chosen to evaluate the model's performance when using the rectified linear unit (relu) activation function and mean absolute difference (MAD) loss function for [Chl-𝑎] retrieval from ABI data, and how reliable is this metric?", '5. How can the model be improved to address the issue of poor generalization to new ABI data obtained on future dates for [Chl-𝑎] retrieval from ABI data?']
# 问题已保存到 Questions(Five)_batch_5.xlsx
# 当前论文: 4384_Combining_fixed-wing_UAV_multispectral_i
# 生成问题： ['1. What spectral detection method was used in the related research of estimating winter wheat NNI at jointing and booting stages?', '2. What feature processing methods can be used based on similar studies when using UAV remote sensing, AM, and FM data to estimate NNI directly in the related research of winter wheat NNI estimation?', '3. What machine learning methods can be applied based on similar studies when using UAV remote sensing, AM, and FM data to estimate PNA and PDM in the related research of winter wheat NNI estimation?', "4. What metric was chosen to evaluate the model's performance when using ML algorithms combined with UAV remote sensing, AM, and FM data to estimate plant dry matter and plant N accumulation in the related research of winter wheat NNI estimation, and how reliable is this metric?", '5. How can the dynamic variation in daily average temperature, accumulated precipitation, and accumulated radiation be utilized in the related research of winter wheat NNI estimation using UAV remote sensing, AM, and FM data?']
# 当前论文: 4386_Monitoring_Dewatering_Fish_Spawning_Site
# 生成问题： ['1. What spectral detection method was used in the related study of evaluating different methods of shoreline detection in various nearshore conditions?', '2. When using the specific spectral detection method in the related study of shoreline detection, what feature processing methods can be applied based on similar research?', '3. When utilizing the specific spectral detection method in the related study of shoreline detection, what machine learning methods have been successful in similar studies?', '4. What metric was chosen to evaluate the performance of models when using the specific spectral detection method in the related study of shoreline detection, and how reliable is this metric?', '5. How can the effectiveness of reservoir drawdown/hydropower operating rules and policies be improved using the specific spectral detection method mentioned in the related study of shoreline detection?']
# 当前论文: 4388_Detecting_coffee_leaf_rust_with_UAV-base
# 生成问题： ['1. What spectral detection method was used in the related research of predicting CLR infection in the plantation field?', '2. What feature processing methods can be applied based on similar studies using the LMT algorithm for predicting CLR infection?', '3. What machine learning methods can be utilized based on similar studies using the LMT algorithm for predicting CLR infection?', "4. What metric was chosen to evaluate the LMT model's performance in predicting CLR infection, and how does it compare to other models?", '5. How does the LMT algorithm differentiate between different classes of CLR infection severity, and what implications does this have for disease control measures?']
# 当前论文: 4393_Ground_Observations_and_Environmental_Co
# 生成问题： ['1. What specific spectral detection method was used in the related study of the Afzar region in Fars province?', '2. What feature processing methods can be applied based on similar studies using the electromagnetic induction device (EMI, Geonics EM38) in the study area?', '3. What machine learning methods have been utilized in similar studies using the electromagnetic induction device (EMI, Geonics EM38) in the study area?', "4. What metric was chosen to evaluate the model's performance in studies using the electromagnetic induction device (EMI, Geonics EM38) in the Afzar region in Fars province, and how reliable is this metric?", '5. How do the geological units and soil types in the study area impact the results obtained using the electromagnetic induction device (EMI, Geonics EM38)?']
# 当前论文: 4399_Diagnosis_of_winter-wheat_water_stress_b
# 生成问题： ['1. What kind of spectral detection method was used in the related research of winter wheat canopy?', '2. How can feature processing methods be applied in the related study of winter wheat canopy using the MCA camera?', '3. What machine learning methods can be utilized in the related research of winter wheat canopy using the MCA camera?', '4. What metric was chosen to evaluate the performance of the model in the related study of winter wheat canopy using the MCA camera, and how effective is this metric?', '5. How can the Grey level co-occurrence matrix (GLCM) be used to evaluate image textures in the study of winter wheat canopy using the MCA camera?']
# 当前论文: 4402_Corn_Nitrogen_Status_Diagnosis_with_an_I
# 生成问题： ['1. What kind of spectral detection method was used in the related research of corn nitrogen status diagnosis with the Crop Circle Phenom sensing system?', '2. What feature processing methods can be used based on similar studies if the Crop Circle Phenom sensing system is used in the related research of corn nitrogen status diagnosis?', '3. What machine learning methods can be used based on similar studies if the Crop Circle Phenom sensing system is used in the related research of corn nitrogen status diagnosis?', "4. What metric was chosen to evaluate the model's performance when using the Crop Circle Phenom sensing system in the related research of corn nitrogen status diagnosis, and how reliable is this metric?", '5. How can the XGB regression model be utilized to improve plant nitrogen status prediction in the research of corn nitrogen status diagnosis using the Crop Circle Phenom sensing system?']
# 当前论文: 4419_Eight_years_of_sub-micrometre_organic_ae
# 生成问题： ['1. What spectral detection method was used in the related study of the classification of mass spectra in the research of sub-micrometre organic aerosol composition data?', '2. When using the k-means clustering method for mass spectra classification in the study of sub-micrometre organic aerosol composition data, what feature processing methods were employed based on similar studies?', '3. In the research on sub-micrometre organic aerosol composition data, what machine learning methods were utilized when applying the k-means clustering method for mass spectra classification?', "4. When using the k-means clustering method for mass spectra classification in the study of sub-micrometre organic aerosol composition data, what metric was chosen to evaluate the model's performance, and how reliable is this metric in assessing the effectiveness of the method?", '5. How were the prevailing organic aerosol types identified in the study of sub-micrometre organic aerosol composition data using the k-means clustering method, and what were the characteristics of each identified cluster?']
# 当前论文: 4422_Estimating_defoliation_of_Scots_pine_sta
# 生成问题： ['1. What spectral detection method was used in the related research of Scots pine stands defoliation assessment at plot level using three ML methods: kNN, RF, and SVM?', '2. When using the spectral detection method in the related research of Scots pine stands defoliation assessment, what feature processing methods can be applied based on similar studies?', '3. When utilizing the spectral detection method in the related research of Scots pine stands defoliation assessment, what machine learning methods can be implemented based on similar studies?', "4. When employing the spectral detection method in the related research of Scots pine stands defoliation assessment, what metric was chosen to evaluate the model's performance, and how reliable is this metric?", '5. How do the confusion matrices obtained from cross-validation compare between the kNN and SVM methods in the related research of Scots pine stands defoliation assessment using the specific spectral detection method?']
# 当前论文: 4434_Evaluation_of_Prescribed_Fires_from_Unma
# 生成问题： ['1. What kind of spectral detection method was used in the related research of burn severity assessment in Sierra de Uría?', '2. What feature processing methods can be applied based on similar studies using the spectral detection method in the study of prescribed fires in Asturias, Spain?', '3. What machine learning methods can be utilized in the related research of forest fires in Asturias, Spain, using the specific spectral detection method mentioned in the study?', "4. What metric was chosen to evaluate the model's performance in the study of prescribed fires in Sierra de Uría using the specific spectral detection method, and how reliable is this metric?", '5. How were the post-fire images collected in the study of prescribed fires in Asturias, Spain, using the specific spectral detection method mentioned in the research?']
# 当前论文: 4436_Towards_Predictive_Modeling_of_Sorghum_B
# 生成问题： ['1. What specific spectral detection method was used in the related research of biomass data collection?', '2. When using the specific spectral detection method in the related research of biomass data collection, what feature processing methods can be implemented based on similar studies?', '3. In the related research of biomass data collection, which machine learning methods can be utilized when employing the specific spectral detection method?', '4. When using the specific spectral detection method in the related research of biomass data collection, what metric was selected to evaluate model performance, and how effective is this metric?', '5. How do the MAE values compare across different machine learning methods in the related research of biomass data collection using the specific spectral detection method?']
# 处理完成！

# %% [markdown]
# 按权重提取出训练的文本

# %%
import pandas as pd
import os
import shutil
import random

# 读取 Excel 文件
excel_file = 'F:\Code\Word_detecting\Label_ver7.xlsx'
df = pd.read_excel(excel_file)

# 统计每个标签的论文数量
label_counts = df['Label6 - Subcategories of Research Methods'].value_counts()

# 计算每个标签需要选取的论文数量，使得总数为500篇，并尽可能平均分配给每个标签
total_selected = 500
selected_per_label = {}
for label, count in label_counts.items():
    selected_per_label[label] = min(int(count / len(label_counts) * total_selected), count)

# 创建保存论文文件夹的目标文件夹
output_folder = 'F:\Code\Word_detecting\Vector_ku\Train_vector'
os.makedirs(output_folder, exist_ok=True)

# 获取大文件夹中所有小文件夹的路径
source_folder = 'F:\Code\Word_detecting\Vector_ku\Save_Vector_Store'
all_folders = [os.path.join(source_folder, folder_name) for folder_name in os.listdir(source_folder)]

# 从所有小文件夹中随机选取相应数量的小文件夹，并复制到目标文件夹中
selected_folders = random.sample(all_folders, total_selected)
for folder in selected_folders:
    shutil.copytree(folder, os.path.join(output_folder, os.path.basename(folder)), dirs_exist_ok=True)

print("论文文件夹已成功保存到指定目标文件夹！")
# Out:
# 论文文件夹已成功保存到指定目标文件夹！

# %% [markdown]
# 合并excel

# %%
import pandas as pd

# 读取 Excel 文件
file_paths = ['Questions(Five)_batch_1.xlsx', 'Questions(Five)_batch_2.xlsx', 'Questions(Five)_batch_3.xlsx', 'Questions(Five)_batch_4.xlsx', 'Questions(Five)_batch_5.xlsx']
dfs = [pd.read_excel(file) for file in file_paths]

# 检查行数是否一致
rows_check = all([dfs[i].shape[1] == dfs[i+1].shape[1] for i in range(len(dfs)-1)])
if not rows_check:
    raise ValueError("行数不一致！")

# 按行拼接DataFrame
merged_df = pd.concat(dfs, axis=0)

# 将结果保存为新的 Excel 文件
merged_df.to_excel('Train_questions.xlsx', index=False)

# %% [markdown]
# 将标签添加到问题文件夹中

# %%
import pandas as pd

# 读取两个 Excel 文件
df1 = pd.read_excel('Label_ver7.xlsx')
df2 = pd.read_excel('Questions with labels.xlsx')

# 提取第一个 Excel 文件的序号和标签列
serial_number_column = df1.iloc[:, 0]  # 假设第一列是序号列
label_column = df1.iloc[:, 11]  # 假设第五列是标签列

# 提取第二个 Excel 文件的论文名称列
paper_names = df2.iloc[:, 0]  # 假设第一列是论文名称列

# 创建一个新的列，并将标签赋值给这一列
labels_for_second_excel = []
for paper_name in paper_names:
    # 提取论文名称中的序号
    try:
        serial_number = int(paper_name.split('_')[0])
    except ValueError:
        print(f"无法解析论文名称 {paper_name} 中的序号。")
        continue
    
    # 在第一个 Excel 文件中找到对应序号的标签
    try:
        label = label_column[serial_number_column == serial_number].values[0]
    except IndexError:
        print(f"无法找到序号为 {serial_number} 的标签。")
        continue
    
    labels_for_second_excel.append(label)

# 将标签赋值给第二个 Excel 文件的新列
df2['标签'] = labels_for_second_excel

# 保存修改后的第二个 Excel 文件
df2.to_excel('modified_second_excel.xlsx', index=False)
